# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load data dari Google Drive
data = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/data_driver.parquet')

from geopy.distance import geodesic
import pandas as pd
from google.colab import drive

# Lokasi penumpang
penumpang_latitude = -6.914163764293244
penumpang_longitude = 107.5217767645688

# Menghitung jarak dan membuat dataframe
df_driver = pd.DataFrame(data)
df_driver['jarak'] = df_driver.apply(lambda driver: geodesic((penumpang_latitude, penumpang_longitude), (driver['latitude'], driver['longitude'])).kilometers, axis=1)

# Mengurutkan berdasarkan jarak
df_driver = df_driver.sort_values('jarak')

# Menampilkan hasil
print("Urutan driver dari yang terdekat hingga terjauh:")
for idx, driver in df_driver.iterrows():
    print(f"{idx+1}. {driver['nama']} - Jarak: {driver['jarak']} kilometer")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Urutan driver dari yang terdekat hingga terjauh:
# 5. Yaya - Jarak: 0.03205836229930533 kilometer
# 3. Wawan - Jarak: 0.0723135909138571 kilometer
# 1. Asep - Jarak: 0.5212870417452979 kilometer
# 4. Tina - Jarak: 1.2520021900956848 kilometer
# 2. Didin - Jarak: 24.410687298155864 kilometer
